# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os
import pandas as pd

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
racialProf = pd.read_csv ("RacialPro_MergedDataset.csv")
print (racialProf.shape)  # Shows number of rows and columns
pd.DataFrame.head (racialProf)
# Out:
# (45274, 43)
#    Unnamed: 0                 Stop_Key  Arrest  Sex_Female/Male  Race_known  \
# 0           0    20201-459626502-25962     0.0              1.0         0.0
# 1           1  2020222-459888916-68495     0.0              1.0         1.0
# 2           2  2020238-459888936-68379     0.0              1.0         0.0
# 3           3  2020244-459639377-68384     0.0              1.0         0.0
# 4           4  2020245-459888941-68382     0.0              0.0         0.0
#
#    Stopped_TrafficViolation  Stopped_City/Highway  Search_Yes/No  \
# 0                       1.0                   1.0            0.0
# 1                       1.0                   1.0            0.0
# 2                       1.0                   1.0            0.0
# 3                       1.0                   1.0            0.0
# 4                       1.0                   1.0            0.0
#
#    Council_District_9  Council_District_7  ...  Stop_Year  Stop_Time  \
# ...

# %%
racialProf = racialProf.drop("Unnamed: 0", axis=1)

# %%
pd.DataFrame.head (racialProf)
# Out:
#                   Stop_Key  Arrest  Sex_Female/Male  Race_known  \
# 0    20201-459626502-25962     0.0              1.0         0.0
# 1  2020222-459888916-68495     0.0              1.0         1.0
# 2  2020238-459888936-68379     0.0              1.0         0.0
# 3  2020244-459639377-68384     0.0              1.0         0.0
# 4  2020245-459888941-68382     0.0              0.0         0.0
#
#    Stopped_TrafficViolation  Stopped_City/Highway  Search_Yes/No  \
# 0                       1.0                   1.0            0.0
# 1                       1.0                   1.0            0.0
# 2                       1.0                   1.0            0.0
# 3                       1.0                   1.0            0.0
# 4                       1.0                   1.0            0.0
#
#    Council_District_9  Council_District_7  Council_District_3  ...  Stop_Year  \
# 0                 1.0                 0.0                 0.0  ...       20.0
# ...

# %%
racialProf.shape
# Out:
# (45274, 42)

# %%
racialProf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45274 entries, 0 to 45273
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Stop_Key                  45271 non-null  object
#  1   Arrest                    45271 non-null  float64
#  2   Sex_Female/Male           45271 non-null  float64
#  3   Race_known                45271 non-null  float64
#  4   Stopped_TrafficViolation  45271 non-null  float64
#  5   Stopped_City/Highway      45271 non-null  float64
#  6   Search_Yes/No             45271 non-null  float64
#  7   Council_District_9        45271 non-null  float64
#  8   Council_District_7        45271 non-null  float64
#  9   Council_District_3        45271 non-null  float64
#  10  Council_District_2        45271 non-null  float64
#  11  Council_District_4        45271 non-null  float64
#  12  Council_District_6        45271 non-null  float64
# ...

# %%
racialProf.describe()
# Out:
#              Arrest  Sex_Female/Male    Race_known  Stopped_TrafficViolation  \
# count  45271.000000     45271.000000  45271.000000              45271.000000
# mean       0.074419         0.635860      0.024077                  0.870646
# std        0.262454         0.481194      0.153291                  0.335595
# min        0.000000         0.000000      0.000000                  0.000000
# 25%        0.000000         0.000000      0.000000                  1.000000
# 50%        0.000000         1.000000      0.000000                  1.000000
# 75%        0.000000         1.000000      0.000000                  1.000000
# max        1.000000         1.000000      1.000000                  1.000000
#
#        Stopped_City/Highway  Search_Yes/No  Council_District_9  \
# count          45271.000000   45271.000000        45271.000000
# mean               0.577898       0.088975            0.147247
# std                0.493900       0.284711            0.354355
# ...

# %%
racialProf = racialProf.rename(columns={"Sex_Female/Male": "Sex_Female1_Male0", 
                              "Stopped_City/Highway": "Stopped_City1_Highway0",
                                "Search_Yes/No": "Search_Yes1_No0",
                                             })

pd.DataFrame.head (racialProf)
# Out:
#                   Stop_Key  Arrest  Sex_Female1_Male0  Race_known  \
# 0    20201-459626502-25962     0.0                1.0         0.0
# 1  2020222-459888916-68495     0.0                1.0         1.0
# 2  2020238-459888936-68379     0.0                1.0         0.0
# 3  2020244-459639377-68384     0.0                1.0         0.0
# 4  2020245-459888941-68382     0.0                0.0         0.0
#
#    Stopped_TrafficViolation  Stopped_City1_Highway0  Search_Yes1_No0  \
# 0                       1.0                     1.0              0.0
# 1                       1.0                     1.0              0.0
# 2                       1.0                     1.0              0.0
# 3                       1.0                     1.0              0.0
# 4                       1.0                     1.0              0.0
#
#    Council_District_9  Council_District_7  Council_District_3  ...  Stop_Year  \
# ...

# %%
# Total number of missing values per column.

Column_NaN_Values = {
                     "Stop_Key": racialProf["Stop_Key"].isna().sum(), 
                     "Arrest": racialProf["Arrest"].isna().sum(),
                     "Sex_Female1_Male0": racialProf["Sex_Female1_Male0"].isna().sum(), 
                     "Race_known": racialProf["Race_known"].isna().sum(),
                    "Stopped_TrafficViolation": racialProf["Stopped_TrafficViolation"].isna().sum(), 
                     "Stopped_City1_Highway0": racialProf["Stopped_City1_Highway0"].isna().sum(),
                        "Search_Yes1_No0": racialProf["Search_Yes1_No0"].isna().sum(),
                        "Council_District_9": racialProf["Council_District_9"].isna().sum(), 
                     "Council_District_7": racialProf["Council_District_7"].isna().sum(),
                     "Council_District_3": racialProf["Council_District_3"].isna().sum(), 
                     "Council_District_2": racialProf["Council_District_2"].isna().sum(),
                    "Council_District_4": racialProf["Council_District_4"].isna().sum(), 
                     "Council_District_6": racialProf["Council_District_6"].isna().sum(),
                        "Council_District_10": racialProf["Council_District_10"].isna().sum(),
    
                        "Council_District_1": racialProf["Council_District_1"].isna().sum(), 
                     "Council_District_5": racialProf["Council_District_5"].isna().sum(),
                     "Council_District_8": racialProf["Council_District_8"].isna().sum(), 
                     "County_Travis": racialProf["County_Travis"].isna().sum(),
                    "Custody": racialProf["Custody"].isna().sum(), 
                     "Other_Sector": racialProf["Other_Sector"].isna().sum(),
                        "Adam_Sector": racialProf["Adam_Sector"].isna().sum(),
                         "Edward_Sector": racialProf["Edward_Sector"].isna().sum(), 
                     "Henry_Sector": racialProf["Henry_Sector"].isna().sum(),
                     "Charlie_Sector": racialProf["Charlie_Sector"].isna().sum(), 
                     "Baker_Sector": racialProf["Baker_Sector"].isna().sum(),
                    "Frank_Sector": racialProf["Frank_Sector"].isna().sum(), 
                     "David_Sector": racialProf["David_Sector"].isna().sum(),
                        "White": racialProf["White"].isna().sum(),
    
                      "Hispanic_Latino": racialProf["Hispanic_Latino"].isna().sum(), 
                     "Black": racialProf["Black"].isna().sum(),
                     "Other_Races": racialProf["Other_Races"].isna().sum(), 
                     "Stop_Month": racialProf["Stop_Month"].isna().sum(),
                    "Stop_Year": racialProf["Stop_Year"].isna().sum(), 
                     "Stop_Time": racialProf["Stop_Time"].isna().sum(),
                        "Location": racialProf["Location"].isna().sum(),
                         "Zip_Code": racialProf["Zip_Code"].isna().sum(), 
                     "latitude": racialProf["latitude"].isna().sum(),
                     "longitude": racialProf["longitude"].isna().sum(), 
                     "propertyTaxRate": racialProf["propertyTaxRate"].isna().sum(),
                    "numPriceChanges": racialProf["numPriceChanges"].isna().sum(), 
                     "avgSchoolRating": racialProf["avgSchoolRating"].isna().sum(),
                        "MedianStudentsPerTeacher": racialProf["MedianStudentsPerTeacher"].isna().sum(),
                            
                            
                    
     
       }
Column_NaN_Values
# Out:
# {'Stop_Key': 3,
#  'Arrest': 3,
#  'Sex_Female1_Male0': 3,
#  'Race_known': 3,
#  'Stopped_TrafficViolation': 3,
#  'Stopped_City1_Highway0': 3,
#  'Search_Yes1_No0': 3,
#  'Council_District_9': 3,
#  'Council_District_7': 3,
#  'Council_District_3': 3,
#  'Council_District_2': 3,
#  'Council_District_4': 3,
#  'Council_District_6': 3,
#  'Council_District_10': 3,
#  'Council_District_1': 3,
#  'Council_District_5': 3,
#  'Council_District_8': 3,
#  'County_Travis': 3,
#  'Custody': 3,
#  'Other_Sector': 3,
#  'Adam_Sector': 3,
#  'Edward_Sector': 3,
#  'Henry_Sector': 3,
#  'Charlie_Sector': 3,
#  'Baker_Sector': 3,
#  'Frank_Sector': 3,
#  'David_Sector': 3,
#  'White': 3,
#  'Hispanic_Latino': 3,
#  'Black': 3,
#  'Other_Races': 3,
#  'Stop_Month': 3,
#  'Stop_Year': 3,
#  'Stop_Time': 3,
#  'Location': 3,
#  'Zip_Code': 0,
#  'latitude': 322,
#  'longitude': 322,
#  'propertyTaxRate': 322,
#  'numPriceChanges': 322,
#  'avgSchoolRating': 322,
#  'MedianStudentsPerTeacher': 322}

# %%
# Dropping the remaining NaN values 
racialProf = racialProf.dropna()
racialProf.shape
# Out:
# (44949, 42)

# %%
# Total number of missing values per column.

Column_NaN_Values = {
                     "Stop_Key": racialProf["Stop_Key"].isna().sum(), 
                     "Arrest": racialProf["Arrest"].isna().sum(),
                     "Sex_Female1_Male0": racialProf["Sex_Female1_Male0"].isna().sum(), 
                     "Race_known": racialProf["Race_known"].isna().sum(),
                    "Stopped_TrafficViolation": racialProf["Stopped_TrafficViolation"].isna().sum(), 
                     "Stopped_City1_Highway0": racialProf["Stopped_City1_Highway0"].isna().sum(),
                        "Search_Yes1_No0": racialProf["Search_Yes1_No0"].isna().sum(),
                        "Council_District_9": racialProf["Council_District_9"].isna().sum(), 
                     "Council_District_7": racialProf["Council_District_7"].isna().sum(),
                     "Council_District_3": racialProf["Council_District_3"].isna().sum(), 
                     "Council_District_2": racialProf["Council_District_2"].isna().sum(),
                    "Council_District_4": racialProf["Council_District_4"].isna().sum(), 
                     "Council_District_6": racialProf["Council_District_6"].isna().sum(),
                        "Council_District_10": racialProf["Council_District_10"].isna().sum(),
    
                        "Council_District_1": racialProf["Council_District_1"].isna().sum(), 
                     "Council_District_5": racialProf["Council_District_5"].isna().sum(),
                     "Council_District_8": racialProf["Council_District_8"].isna().sum(), 
                     "County_Travis": racialProf["County_Travis"].isna().sum(),
                    "Custody": racialProf["Custody"].isna().sum(), 
                     "Other_Sector": racialProf["Other_Sector"].isna().sum(),
                        "Adam_Sector": racialProf["Adam_Sector"].isna().sum(),
                         "Edward_Sector": racialProf["Edward_Sector"].isna().sum(), 
                     "Henry_Sector": racialProf["Henry_Sector"].isna().sum(),
                     "Charlie_Sector": racialProf["Charlie_Sector"].isna().sum(), 
                     "Baker_Sector": racialProf["Baker_Sector"].isna().sum(),
                    "Frank_Sector": racialProf["Frank_Sector"].isna().sum(), 
                     "David_Sector": racialProf["David_Sector"].isna().sum(),
                        "White": racialProf["White"].isna().sum(),
    
                      "Hispanic_Latino": racialProf["Hispanic_Latino"].isna().sum(), 
                     "Black": racialProf["Black"].isna().sum(),
                     "Other_Races": racialProf["Other_Races"].isna().sum(), 
                     "Stop_Month": racialProf["Stop_Month"].isna().sum(),
                    "Stop_Year": racialProf["Stop_Year"].isna().sum(), 
                     "Stop_Time": racialProf["Stop_Time"].isna().sum(),
                        "Location": racialProf["Location"].isna().sum(),
                         "Zip_Code": racialProf["Zip_Code"].isna().sum(), 
                     "latitude": racialProf["latitude"].isna().sum(),
                     "longitude": racialProf["longitude"].isna().sum(), 
                     "propertyTaxRate": racialProf["propertyTaxRate"].isna().sum(),
                    "numPriceChanges": racialProf["numPriceChanges"].isna().sum(), 
                     "avgSchoolRating": racialProf["avgSchoolRating"].isna().sum(),
                        "MedianStudentsPerTeacher": racialProf["MedianStudentsPerTeacher"].isna().sum(),
                            
                            
                    
     
       }
Column_NaN_Values
# Out:
# {'Stop_Key': 0,
#  'Arrest': 0,
#  'Sex_Female1_Male0': 0,
#  'Race_known': 0,
#  'Stopped_TrafficViolation': 0,
#  'Stopped_City1_Highway0': 0,
#  'Search_Yes1_No0': 0,
#  'Council_District_9': 0,
#  'Council_District_7': 0,
#  'Council_District_3': 0,
#  'Council_District_2': 0,
#  'Council_District_4': 0,
#  'Council_District_6': 0,
#  'Council_District_10': 0,
#  'Council_District_1': 0,
#  'Council_District_5': 0,
#  'Council_District_8': 0,
#  'County_Travis': 0,
#  'Custody': 0,
#  'Other_Sector': 0,
#  'Adam_Sector': 0,
#  'Edward_Sector': 0,
#  'Henry_Sector': 0,
#  'Charlie_Sector': 0,
#  'Baker_Sector': 0,
#  'Frank_Sector': 0,
#  'David_Sector': 0,
#  'White': 0,
#  'Hispanic_Latino': 0,
#  'Black': 0,
#  'Other_Races': 0,
#  'Stop_Month': 0,
#  'Stop_Year': 0,
#  'Stop_Time': 0,
#  'Location': 0,
#  'Zip_Code': 0,
#  'latitude': 0,
#  'longitude': 0,
#  'propertyTaxRate': 0,
#  'numPriceChanges': 0,
#  'avgSchoolRating': 0,
#  'MedianStudentsPerTeacher': 0}

# %%
racialProf.head()
# Out:
#                   Stop_Key  Arrest  Sex_Female1_Male0  Race_known  \
# 0    20201-459626502-25962     0.0                1.0         0.0
# 1  2020222-459888916-68495     0.0                1.0         1.0
# 2  2020238-459888936-68379     0.0                1.0         0.0
# 3  2020244-459639377-68384     0.0                1.0         0.0
# 4  2020245-459888941-68382     0.0                0.0         0.0
#
#    Stopped_TrafficViolation  Stopped_City1_Highway0  Search_Yes1_No0  \
# 0                       1.0                     1.0              0.0
# 1                       1.0                     1.0              0.0
# 2                       1.0                     1.0              0.0
# 3                       1.0                     1.0              0.0
# 4                       1.0                     1.0              0.0
#
#    Council_District_9  Council_District_7  Council_District_3  ...  Stop_Year  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

racialProf.hist(bins=50, figsize=(25,20))
#save_fig("attribute_histogram_plots")
plt.show()

# %%
df_price = df_new['price']
df_price.plot(kind = 'box', figsize=(8,6))
df_price.head()

# %%
racialProf.plot(kind="scatter", x="longitude", y="latitude")
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
racialProf.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
    s=racialProf["avgSchoolRating"]/100, label="avgSchoolRating", figsize=(10,7),
    c="MedianStudentsPerTeacher", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()
#save_fig("housing_prices_scatterplot")
